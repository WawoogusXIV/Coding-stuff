# %%
from datetime import date
from datetime import datetime

today = date.today()
with open("today.txt", "w") as file:
    file.write(str(today))
with open("today.txt", "r") as file:
    today_string = file.read()

parsed_date = datetime.strptime(today_string, "%Y-%m-%d").date()

print(parsed_date)

import multiprocessing
import time
import random

def worker():
    delay = random.random()
    time.sleep(delay)

    print(f"Process {multiprocessing.current_process().name} "
          f"woke up after {delay:.3f}s at {datetime.now()}")

if __name__ == "__main__":
    processes = []
    for i in range(3):
        p = multiprocessing.Process(target=worker, name=f"P{i+1}")
        processes.append(p)
        p.start()
    
    for p in processes:
        p.join()

# %%
Overall, even more interesting stuff.  Writing and reading files is really
important to know in software development, which is why I'm glad that I 
got to learn how to do it.

Pretty simple stuff though.
