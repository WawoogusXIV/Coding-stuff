# %%
def hours():
    print("Open 9-5 daily")


>>> import zoo
>>> zoo.hours()
Open 9-5 daily
>>> import zoo as menegerie
>>> import zoo as menagerie
>>> menagerie.hours        
<function hours at 0x000001838CFC1260>
>>> menagerie.hours()
Open 9-5 daily
>>>
